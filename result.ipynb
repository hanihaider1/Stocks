# %%
from final_stocks import Stocks
value = Stocks("PYPL.csv","SQ.csv")
value.summary()
# Out:
# <style  type="text/css" >
#     #T_80c66414_a5d5_11eb_8739_9801a78a5cfdrow0_col0 {
#             text-align:  center;
#         }    #T_80c66414_a5d5_11eb_8739_9801a78a5cfdrow0_col1 {
#             text-align:  center;
#         }    #T_80c66414_a5d5_11eb_8739_9801a78a5cfdrow0_col2 {
#             text-align:  center;
#         }    #T_80c66414_a5d5_11eb_8739_9801a78a5cfdrow0_col3 {
#             text-align:  center;
#         }    #T_80c66414_a5d5_11eb_8739_9801a78a5cfdrow0_col4 {
#             text-align:  center;
#         }    #T_80c66414_a5d5_11eb_8739_9801a78a5cfdrow1_col0 {
#             text-align:  center;
#         }    #T_80c66414_a5d5_11eb_8739_9801a78a5cfdrow1_col1 {
#             text-align:  center;
#         }    #T_80c66414_a5d5_11eb_8739_9801a78a5cfdrow1_col2 {
#             text-align:  center;
#         }    #T_80c66414_a5d5_11eb_8739_9801a78a5cfdrow1_col3 {
#             text-align:  center;
#         }    #T_80c66414_a5d5_11eb_8739_9801a78a5cfdrow1_col4 {
# ...

# %%
value.graph()

# %%
value.stock_comparison_graph()

# %%
value.comparing_summary()
# Out:
# <style  type="text/css" >
#     #T_94946cca_a5d5_11eb_8739_9801a78a5cfdrow0_col0 {
#             text-align:  center;
#         }    #T_94946cca_a5d5_11eb_8739_9801a78a5cfdrow0_col1 {
#             text-align:  center;
#         }    #T_94946cca_a5d5_11eb_8739_9801a78a5cfdrow0_col2 {
#             text-align:  center;
#         }    #T_94946cca_a5d5_11eb_8739_9801a78a5cfdrow0_col3 {
#             text-align:  center;
#         }    #T_94946cca_a5d5_11eb_8739_9801a78a5cfdrow1_col0 {
#             text-align:  center;
#         }    #T_94946cca_a5d5_11eb_8739_9801a78a5cfdrow1_col1 {
#             text-align:  center;
#         }    #T_94946cca_a5d5_11eb_8739_9801a78a5cfdrow1_col2 {
#             text-align:  center;
#         }    #T_94946cca_a5d5_11eb_8739_9801a78a5cfdrow1_col3 {
#             text-align:  center;
#         }</style>
# <table id="T_94946cca_a5d5_11eb_8739_9801a78a5cfd" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >summary</th>
# ...

# %%
value1 = Stocks("PYPL.csv")

# %%
value1.comparing_summary()#should raise error as we have not given the second file name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-0c0b0278539d> in <module>
# ----> 1 value1.comparing_summary()#should raise error as we have not given the second file name
#
# ~/Stocks/final_stocks.py in comparing_summary(self)
#     240         self.rasing_error(self.stocks_filename)
#     241
# --> 242         value1, value2 = self.stock()
#     243
#     244         summary = {'summary': [self.stocks_filename, self.stocks_filename2], 'Highest High': [value1[0], value2[0]],
#
# ~/Stocks/final_stocks.py in stock(self)
#     209         min_value = self.stock_file.loc[self.stock_file['Close'].idxmin()]
#     210
# --> 211         max_value1 = self.stock_file2.loc[self.stock_file2['Close'].idxmax()]
#     212         min_value1 = self.stock_file2.loc[self.stock_file2['Close'].idxmin()]
#     213
#
# AttributeError: 'Stocks' object has no attribute 'stock_file2'

# %%
value1.stock_comparison_graph()#should raise error as we have not given the second file name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-d63dd3390a27> in <module>
# ----> 1 value1.stock_comparison_graph()
#
# ~/Stocks/final_stocks.py in stock_comparison_graph(self)
#     189         '''
#     190
# --> 191         output1 = self.transform_data()
#     192         output1.plot(x="Date")
#     193         plt.title("Closing Prices", fontsize=16)
#
# ~/Stocks/final_stocks.py in transform_data(self)
#     174
#     175         output1 = pd.merge(
# --> 176             self.df_compare, self.df2_compare, on='Date', how='inner')
#     177         output1.columns = ['Date', self.stocks_filename, self.stocks_filename2]
#     178
#
# AttributeError: 'Stocks' object has no attribute 'df_compare'

# %%
value1.summary()
# Out:
# <style  type="text/css" >
#     #T_265b392c_a5d6_11eb_8739_9801a78a5cfdrow0_col0 {
#             text-align:  center;
#         }    #T_265b392c_a5d6_11eb_8739_9801a78a5cfdrow0_col1 {
#             text-align:  center;
#         }    #T_265b392c_a5d6_11eb_8739_9801a78a5cfdrow0_col2 {
#             text-align:  center;
#         }    #T_265b392c_a5d6_11eb_8739_9801a78a5cfdrow0_col3 {
#             text-align:  center;
#         }    #T_265b392c_a5d6_11eb_8739_9801a78a5cfdrow0_col4 {
#             text-align:  center;
#         }    #T_265b392c_a5d6_11eb_8739_9801a78a5cfdrow1_col0 {
#             text-align:  center;
#         }    #T_265b392c_a5d6_11eb_8739_9801a78a5cfdrow1_col1 {
#             text-align:  center;
#         }    #T_265b392c_a5d6_11eb_8739_9801a78a5cfdrow1_col2 {
#             text-align:  center;
#         }    #T_265b392c_a5d6_11eb_8739_9801a78a5cfdrow1_col3 {
#             text-align:  center;
#         }    #T_265b392c_a5d6_11eb_8739_9801a78a5cfdrow1_col4 {
# ...

# %%
value1.graph()
